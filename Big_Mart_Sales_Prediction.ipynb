# %% [markdown]
# # 1. Importing Dependencies

# %%
import pandas as pd                         # Import pandas for data manipulation and analysis (handling DataFrames)
import numpy as np                          # Import NumPy for numerical computations and working with arrays
import matplotlib.pyplot as plt             # Import Matplotlib for creating visualizations and plots
import seaborn as sns                       # Import Seaborn for advanced and attractive statistical visualizations
from sklearn.preprocessing import LabelEncoder  # Import LabelEncoder to convert categorical text data into numerical labels
from sklearn.model_selection import train_test_split  # Import train_test_split to divide the dataset into training and testing sets
from xgboost import XGBRegressor            # Import XGBRegressor, a powerful gradient boosting algorithm for regression tasks
from sklearn import metrics                 # Import metrics to evaluate model performance (e.g., accuracy, MAE, R² score)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Data Loading and Processing

# %%
df = pd.read_csv('BIG MART Train.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# Checking the first five rows of our data
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Checking the last five rows of our data
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
# The number of data points and number of features
df.shape
# Out:
# (8523, 12)

# %%
# Getting information about our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# The categorical features that we have in our dataset include;
# 1. Item_Identifier
# 2. Item_Fat_Content
# 3. Item_Type
# 4. Outlet_Identifier
# 5. Outlet_Size
# 6. Outlet_Location_Type
# 7. Outlet_Type

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# # 3. Handling Missing Values

# %% [markdown]
# Mean and Mode methods of handling missing values

# %% [markdown]
# Replacing The Missing Values in Item_Weight Using Mean

# %%
# Mean value of Item_Weight
df['Item_Weight'].mean()
# Out:
# np.float64(12.857645184135976)

# %%
# Filling the missing values in Item_Weight column with the mean value
df['Item_Weight'] = df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# Replacing Missing Values in Outlet_Size using Mode

# %%
# Create a pivot table to find the most frequent (mode) Outlet_Size for each Outlet_Type
mode_of_Outlet_Size = df.pivot_table(
    values='Outlet_Size',                    # The column we want to analyze
    columns='Outlet_Type',                   # Group data by the type of outlet
    aggfunc=(lambda x: x.mode()[0])          # Apply a function that returns the most common (mode) value
)

# Display the resulting pivot table showing the mode Outlet_Size for every Outlet_Type
print(mode_of_Outlet_Size)
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
missing_values  = df['Outlet_Size'].isnull()

# %%
print(missing_values)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8518    False
# 8519     True
# 8520    False
# 8521    False
# 8522    False
# Name: Outlet_Size, Length: 8523, dtype: bool

# %%
# Finding the missing values
df.loc[missing_values, 'Outlet_Size'] = df.loc[missing_values, 'Outlet_Type'].apply(lambda x: mode_of_Outlet_Size[x])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# # 4. Data Analysis

# %%
# Getting the statistical measures of our dataset
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# # 5. Getting Plots for our Numerical Features

# %%
sns.set()

# %%
# Item_Weight Distribution
plt.figure(figsize=(6, 6))
sns.distplot(df['Item_Weight'])
plt.show()

# %%
# Item_Visibility Distribution
plt.figure(figsize=(6, 6))
sns.distplot(df['Item_Visibility'])
plt.show();

# %%
# Item_MRP Distribution
plt.figure(figsize=(6, 6))
sns.distplot(df['Item_MRP'])
plt.show()

# %%
# Item_Outlet_Sales Distribution
plt.figure(figsize=(6, 6))
sns.distplot(df['Item_Outlet_Sales'])
plt.show()

# %%
# Outlet_Establishment_Year Distribution
plt.figure(figsize=(6, 6))
sns.countplot(x = 'Outlet_Establishment_Year', data = df)
plt.show()

# %% [markdown]
# # 6. Getting Plots for our Categorical Features

# %%
# Item_Fat_Content Distribution
plt.figure(figsize=(6, 6))
sns.countplot(x = 'Item_Fat_Content', data = df)
plt.show()

# %%
# Item_Type Distribution
plt.figure(figsize=(20, 6))
sns.countplot(x = 'Item_Type', data = df)
plt.xticks(rotation=90)
plt.show()

# %%
# Outlet_Size Distribution
plt.figure(figsize=(6, 6))
sns.countplot(x = 'Outlet_Size', data = df)
plt.show()

# %%
# Outlet_Location_Type Distribution
plt.figure(figsize=(6, 6))
sns.countplot(x = 'Outlet_Location_Type', data = df)
plt.show()

# %%
# Outlet_Type Distribution
plt.figure(figsize=(10, 10))
sns.countplot(x = 'Outlet_Type', data = df)
plt.show()

# %%
# Replacing the fat content column
df.replace({'Item_Fat_Content': {'low fat':'Low Fat', 'LF':'Low Fat', 'reg':'Regular'}}, inplace=True)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %% [markdown]
# # 7. Label Encoding

# %%
encoder = LabelEncoder()

# %%
# Transforming all the seven Categoricat Columns
df['Item_Identifier'] = encoder.fit_transform(df['Item_Identifier'])
df['Item_Fat_Content'] = encoder.fit_transform(df['Item_Fat_Content'])
df['Item_Type'] = encoder.fit_transform(df['Item_Type'])
df['Outlet_Identifier'] = encoder.fit_transform(df['Outlet_Identifier'])
df['Outlet_Size'] = encoder.fit_transform(df['Outlet_Size'])
df['Outlet_Location_Type'] = encoder.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Type'] = encoder.fit_transform(df['Outlet_Type'])

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            2
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# # 8. Splitting Our Data into Features and Targets

# %%
X = df.drop(columns = 'Item_Outlet_Sales', axis = 1)
Y = df['Item_Outlet_Sales']

# %%
X
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156        9.300                 0         0.016047
# 1                   8        5.920                 1         0.019278
# 2                 662       17.500                 0         0.016760
# 3                1121       19.200                 1         0.000000
# 4                1297        8.930                 0         0.000000
# ...               ...          ...               ...              ...
# 8518              370        6.865                 0         0.056783
# 8519              897        8.380                 1         0.046982
# 8520             1357       10.600                 0         0.035186
# 8521              681        7.210                 1         0.145221
# 8522               50       14.800                 0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
Y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %% [markdown]
# # 9. Splitting Our Data Into Training and Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (8523, 11) (6818, 11) (1705, 11)

# %% [markdown]
# # 10. Training Our Model

# %%
model = XGBRegressor()

# %% [markdown]
# # 11. Fitting our model

# %%
model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# # 12. Model Evaluation

# %%
# Prediction on Training Data
training_data_prediction = model.predict(X_train)

# %%
# R Squared Value
r2_train = metrics.r2_score(Y_train, training_data_prediction)
print('R Squared Value: ', r2_train)
# Out:
# R Squared Value:  0.8762174618111388

# %%
# Prediction on Testing Data
test_data_prediction = model.predict(X_test)

# %%
# R squared Value
r2_test = metrics.r2_score(Y_test, test_data_prediction)
print('R Squared Value: ', r2_test)
# Out:
# R Squared Value:  0.5017253991620692
